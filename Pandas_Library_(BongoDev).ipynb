# %% [markdown]
# <a href="https://colab.research.google.com/github/Ab-Rouf/Full_pandas/blob/main/Pandas_Library_(BongoDev).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas :
# 1. pandas is a python library for tabular data.
# 2. pandas analyze , clean , explore, manipulate .
# 3. Pandas allows us to analyze big data and make conlusions based on statistical theories.
#
# Objectives:
#
# 1. Data frame
# 2. Dataframe attributes and methods
# 3. pandas operation .

# %%
import pandas as pd

# %%
#create dataframe from dictionary
health_data_table={
    "height":[5.5,5.5,None,5.8],
    "weight":[57,72,68,90],
    "BMI":[19.3,12.7,20.3,18.5]
}
health_data_table=pd.DataFrame(health_data_table)
health_data_table
# Out:
#    height  weight   BMI
# 0     5.5      57  19.3
# 1     5.5      72  12.7
# 2     NaN      68  20.3
# 3     5.8      90  18.5

# %%
print(type(health_data_table))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
health_data_table.head(2)
# Out:
#    height  weight   BMI
# 0     5.5      57  19.3
# 1     5.5      72  12.7

# %%
health_data_table.tail(2)
# Out:
#    height  weight   BMI
# 2     NaN      68  20.3
# 3     5.8      90  18.5

# %%
health_data_table.shape
# Out:
# (4, 3)

# %%
#basic information for this table
health_data_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  3 non-null      float64
#  1   weight  4 non-null      int64
#  2   BMI     4 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 228.0 bytes

# %%
# calculate the count, mean, std(stander deviation), min,max ans % of data
health_data_table.describe()
# Out:
#          height     weight        BMI
# count  3.000000   4.000000   4.000000
# mean   5.600000  71.750000  17.700000
# std    0.173205  13.720423   3.413698
# min    5.500000  57.000000  12.700000
# 25%    5.500000  65.250000  17.050000
# 50%    5.500000  70.000000  18.900000
# 75%    5.650000  76.500000  19.550000
# max    5.800000  90.000000  20.300000

# %%
values=health_data_table.values
print(values)
# Out:
# [[ 5.5 57.  19.3]
#  [ 5.5 72.  12.7]
#  [ nan 68.  20.3]
#  [ 5.8 90.  18.5]]

# %%
print(type(values))
# Out:
# <class 'numpy.ndarray'>

# %%
cols=health_data_table.columns
print(cols)
# Out:
# Index(['height', 'weight', 'BMI'], dtype='object')

# %%
health_data_table.columns=[
    "height(Feet)", "weight(kg)", "BMI"
]

# %%
health_data_table.head()
# Out:
#    height(Feet)  weight(kg)   BMI
# 0           5.5          57  19.3
# 1           5.5          72  12.7
# 2           NaN          68  20.3
# 3           5.8          90  18.5

# %%
# save this data frame.
health_data_table.to_csv(
    path_or_buf="health_data_df.csv",
    index=False #index value save hobe nah
)

# %%
df=pd.read_csv("health_data_df.csv")
df.head()
# Out:
#    height(Feet)  weight(kg)   BMI
# 0           5.5          57  19.3
# 1           5.5          72  12.7
# 2           NaN          68  20.3
# 3           5.8          90  18.5

# %%
df.head()
# Out:
#    height(Feet)  weight(kg)   BMI
# 0           5.5          57  19.3
# 1           5.5          72  12.7
# 2           NaN          68  20.3
# 3           5.8          90  18.5

# %%
df=pd.read_csv("/content/homeless_prep.csv")
df.head(5)
# Out:
#    CLIENT_KEY  AGE  GENDER VETERAN  INCOME  NIGHTS  substanceabuse  completed  \
# 0      256172   20  Female      No     0.0   152.0               0          0
# 1      221079   20  Female      No   740.0   229.0               0          1
# 2      243074   21  Female      No     0.0   105.0               1          1
# 3      129974   21  Female      No     0.0   371.0               1          1
# 4      226596   22  Female      No     0.0   169.0               0          0
#
#    probation  assistancetype  required
# 0          1  tempassistance         1
# 1          0  tempassistance         1
# 2          0  tempassistance         1
# 3          0  tempassistance         1
# 4          0  tempassistance         1

# %%
# sorting data
sorted_df=df.sort_values(
    by=["AGE", "NIGHTS"],
    ascending=[True, True]
)
sorted_df.head(10)
# Out:
#      CLIENT_KEY  AGE  GENDER VETERAN  INCOME  NIGHTS  substanceabuse  \
# 0        256172   20  Female      No     0.0   152.0               0
# 121      256172   20  Female      No     0.0   152.0               0
# 1        221079   20  Female      No   740.0   229.0               0
# 122      221079   20  Female      No   740.0   229.0               0
# 2        243074   21  Female      No     0.0   105.0               1
# 123      243074   21  Female      No     0.0   105.0               1
# 3        129974   21  Female      No     0.0   371.0               1
# 124      129974   21  Female      No     0.0   371.0               1
# 4        226596   22  Female      No     0.0   169.0               0
# 125      226596   22  Female      No     0.0   169.0               0
#
#      completed  probation  assistancetype  required
# 0            0          1  tempassistance         1
# 121          0          1  permassistance         1
# ...

# %%
#individual column select
individual_col=df[["AGE","GENDER"]]
print(individual_col)
# Out:
#      AGE  GENDER
# 0     20  Female
# 1     20  Female
# 2     21  Female
# 3     21  Female
# 4     22  Female
# ..   ...     ...
# 237   77    Male
# 238   77  Female
# 239   79    Male
# 240   79  Female
# 241   79  Female
#
# [242 rows x 2 columns]

# %%
#select the individual row and column
max=df[df["AGE"]>30]
print(max)
# Out:
#      CLIENT_KEY  AGE  GENDER VETERAN   INCOME  NIGHTS  substanceabuse  \
# 32       230886   31  Female      No   861.22    92.0               0
# 33       127341   31  Female      No  1410.76    96.0               1
# 34       120235   31  Female      No     0.00   103.0               1
# 35       284910   32  Female      No   831.00    90.0               0
# 36       292407   32  Female      No   838.00    90.0               0
# ..          ...  ...     ...     ...      ...     ...             ...
# 237      204806   77    Male     Yes     0.00    12.0               0
# 238      320878   77  Female     Yes  1331.02    25.0               0
# 239      213114   79    Male     Yes  2100.00    11.0               0
# 240      258969   79  Female     Yes   694.00    16.0               0
# 241       84396   79  Female     Yes     0.00    22.0               0
#
#      completed  probation  assistancetype  required
# 32           1          1  tempassistance         1
# ...

# %%
gender_wise=df[df["GENDER"]=="Male"]
print(gender_wise)
# Out:
#      CLIENT_KEY  AGE GENDER VETERAN   INCOME  NIGHTS  substanceabuse  \
# 14       280713   25   Male      No   674.00   179.0               0
# 27       219786   30   Male      No     0.00    98.0               1
# 42       102556   33   Male      No  1108.00    92.0               0
# 43       221912   33   Male      No   640.00    92.0               0
# 56        97872   36   Male      No   687.50   111.0               1
# 61       251589   38   Male      No   726.91    75.0               0
# 73       104923   40   Male      No   314.16    92.0               0
# 76       292075   43   Male     Yes  1001.00    54.0               0
# 90       148256   49   Male     Yes  1174.00    39.0               0
# 91       321119   49   Male     Yes   857.00    48.0               0
# 93       264412   50   Male     Yes     0.00     6.0               0
# 96       138506   52   Male     Yes   700.00     3.0               0
# 101      235982   57   Male     Yes     0.00    34.0               0
# ...

# %%
gender_wise=df[df["GENDER"]=="Male"]
income_wise=df[df["INCOME"]>2000]
new_df=df[(df["GENDER"]=="Male") & (df["INCOME"]>2000)]
new_df.head()
# Out:
#      CLIENT_KEY  AGE GENDER VETERAN  INCOME  NIGHTS  substanceabuse  \
# 107       87939   60   Male      No  2974.0    25.0               1
# 118      213114   79   Male     Yes  2100.0    11.0               0
# 228       87939   60   Male      No  2974.0    25.0               1
# 239      213114   79   Male     Yes  2100.0    11.0               0
#
#      completed  probation  assistancetype  required
# 107          1          0  tempassistance         0
# 118          1          0  tempassistance         1
# 228          1          0  permassistance         0
# 239          1          0  permassistance         0

# %%
#create a new column
df["new_col"]=df["AGE"]+df["NIGHTS"]
df.head()
# Out:
#    CLIENT_KEY  AGE  GENDER VETERAN  INCOME  NIGHTS  substanceabuse  completed  \
# 0      256172   20  Female      No     0.0   152.0               0          0
# 1      221079   20  Female      No   740.0   229.0               0          1
# 2      243074   21  Female      No     0.0   105.0               1          1
# 3      129974   21  Female      No     0.0   371.0               1          1
# 4      226596   22  Female      No     0.0   169.0               0          0
#
#    probation  assistancetype  required  new_col
# 0          1  tempassistance         1    172.0
# 1          0  tempassistance         1    249.0
# 2          0  tempassistance         1    126.0
# 3          0  tempassistance         1    392.0
# 4          0  tempassistance         1    191.0

# %%
new_df_for_mean=df["INCOME"]
mean=new_df_for_mean.mean()
sum=new_df_for_mean.sum()
std=new_df_for_mean.std()
min=new_df_for_mean.min()
max=new_df_for_mean.max()
print("mean",mean)
print("sum",sum)
print("std",std)
print("min",min)
print("max",max)
# Out:
# mean 661.5496694214877
# sum 160095.02000000002
# std 1221.7735161083617
# min 0.0
# max 12583.34

# %% [markdown]
# #Advance pandas

# %%
"""
Workflow of a data scientist:
1. Data cleaning: Handle missing values,remove duplicates,remove outliers,standardize the data.
2. Exploratory Data Analysis :
    explore data pattern and distribution of data.
    summary statistics,data visualization.
3. Feature Engineering:
    Selection of most relevant features
    For example we have table containing weather data.
    |Data|termparature|Humidity|wind speed|probability rain (%)
    X={x1,x2,x3,x4}
    Y=f{x}
    ML/AI/DL estimates a function f that maps X into Y. this function estimation is done by designing an ML algorithm, Artificial Network.
    Reduce dimensionality of data.
4. Data Transformation: Normalization,Encoding categorical data.
    f(x)= T + H +WS = 25 + 70 + 5=100

5. Data Splitting
6.



"""
# Out:
# '\nWorkflow of a data scientist:\n1. Data cleaning: Handle missing values,remove duplicates,remove outliers,standardize the data.\n2. Exploratory Data Analysis :\n    explore data pattern and distribution of data.\n    summary statistics,data visualization.\n3. Feature Engineering:\n    Selection of most relevant features\n    For example we have table containing weather data.\n    |Data|termparature|Humidity|wind speed|probability rain (%)\n    X={x1,x2,x3,x4}\n    Y=f{x}\n    ML/AI/DL estimates a function f that maps X into Y. this function estimation is done by designing an ML algorithm, Artificial Network.\n    Reduce dimensionality of data.\n4. Data Transformation: Normalization,Encoding categorical data.\n    f(x)= T + H +WS = 25 + 70 + 5=100\n\n5. Data Splitting\n6.\n\n\n\n'

# %%
import pandas as pd
import os

# %% [markdown]
# #Load data

# %%
import os

dataset_path = r"C:\Users\Abdur Rouf\Desktop\Pandas Libraby\data\Health Monitor Dataset.csv"
print(os.path.exists(dataset_path))  # Should return True if file exists
# Out:
# False

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("themrityunjaypathak/pandas-practice-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 493/493 [00:00<00:00, 827kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/themrityunjaypathak/pandas-practice-dataset/versions/1

# %%
import os
print(os.listdir(path))
# Out:
# ['data.csv']

# %%
import os
health_monitor_data=pd.read_csv(os.path.join(path, "data.csv"))
health_monitor_data.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %% [markdown]
# #Data cleaning

# %%
health_monitor_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
"""Handle missing values
approach 1: Remove rows (When tha dataset is large enough)
approach 2: Replace missing values with mean,median,mode .
approach 3: input missing values(when the dataset is small)


"""

mask=health_monitor_data.isnull()
print(mask)
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
#column wise missing data . (true means missing one or more data)

mask=health_monitor_data.isnull().any()
print(mask)
# Out:
# Duration    False
# Date         True
# Pulse       False
# Maxpulse    False
# Calories     True
# dtype: bool

# %%
# row wise missing value
mask=health_monitor_data.isnull().any(axis=1)
print(mask)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
# all missing value
health_monitor_data[mask]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 18        45  '2020/12/18'     90       112       NaN
# 22        45           NaN    100       119     282.0
# 28        60  '2020/12/28'    103       132       NaN

# %%
average_val=health_monitor_data['Calories'].mean()
print('Average calories: {}'.format(average_val))
# Out:
# Average calories: 304.68

# %%
health_monitor_data['Calories']=health_monitor_data['Calories'].fillna(
    value=average_val

)

print(health_monitor_data )
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
#again show the nll value
mask=health_monitor_data.isnull().any(axis=1)
health_monitor_data[mask]
# Out:
#     Duration Date  Pulse  Maxpulse  Calories
# 22        45  NaN    100       119     282.0

# %%
# row selection kore delete kore dibo. karon date mean kore replace kora jay na
health_monitor_data=health_monitor_data.dropna()
health_monitor_data.isnull().sum()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
health_monitor_data.to_csv("clean_data.csv",index=False)

# %%
# Remove duplicate data

mask=health_monitor_data.duplicated()
print(mask)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
health_monitor_data[mask]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 12        60  '2020/12/12'    100       120     250.7

# %%
health_monitor_data=health_monitor_data.drop_duplicates()

# %%
health_monitor_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# convert data type
health_monitor_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  30 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     30 non-null     int64
#  3   Maxpulse  30 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
health_monitor_data['Date']=health_monitor_data['Date'].astype('datetime64[ns]')
health_monitor_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  30 non-null     int64
#  1   Date      30 non-null     datetime64[ns]
#  2   Pulse     30 non-null     int64
#  3   Maxpulse  30 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.4 KB

# %%
"""
Remove outliers using interQuantile range.
IQR=Q3-Q1
L=Q1-1.5*IQR
R=Q3+1.5*IQR
"""
Q1=health_monitor_data['Pulse'].quantile(0.25)
Q3=health_monitor_data['Pulse'].quantile(0.75)
print(Q1)
print(Q3)

IQR=Q3-Q1
print(IQR)

L=Q1-1.5*IQR
R=Q3+1.5*IQR
print(L)
print(R)
# Out:
# 100.0
# 107.5
# 7.5
# 88.75
# 118.75

# %%
non_outlier_mask=health_monitor_data['Pulse'].between(L, R)
outlier_mask=~non_outlier_mask

# print(outlier_mask)
health_monitor_data[outlier_mask]
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 23        60 2020-12-23    130       101     300.0

# %%
health_monitor_data=health_monitor_data[non_outlier_mask]
health_monitor_data.head()
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 0        60 2020-12-01    110       130     409.1
# 1        60 2020-12-02    117       145     479.0
# 2        60 2020-12-03    103       135     340.0
# 3        45 2020-12-04    109       175     282.4
# 4        45 2020-12-05    117       148     406.0

# %% [markdown]
# #Exploratory Data Analysis

# %%
health_monitor_data.describe()
# Out:
#          Duration                           Date       Pulse    Maxpulse  \
# count   29.000000                             29   29.000000   29.000000
# mean    69.827586  2020-12-15 13:14:28.965517312  102.827586  130.068966
# min     30.000000            2020-12-01 00:00:00   90.000000  112.000000
# 25%     60.000000            2020-12-08 00:00:00  100.000000  123.000000
# 50%     60.000000            2020-12-15 00:00:00  103.000000  129.000000
# 75%     60.000000            2020-12-24 00:00:00  106.000000  133.000000
# max    450.000000            2020-12-31 00:00:00  117.000000  175.000000
# std     73.514852                            NaN    6.442432   12.317035
#
#          Calories
# count   29.000000
# mean   307.484828
# min    195.100000
# 25%    250.700000
# 50%    300.000000
# 75%    345.300000
# max    479.000000
# std     66.187018

# %% [markdown]
# #Feature Engineering

# %%
"""
Select the most relevant features by experience or applying feature selection algorithms.

"""
# Out:
# '\nSelect the most relevant features by experience or applying feature selection algorithms.\n\n'

# %% [markdown]
# #Data Transformation

# %%
"""
data can numeric or categorical

Numeric: We need to normalize out data
Categorical: We need to encode categorical data.
"""
def normalize(col):
  mean=col.mean()
  std=col.std()
  return (col-mean)/std

health_monitor_data['Pulse']=health_monitor_data['Pulse'].agg(normalize)
health_monitor_data['Maxpulse']=health_monitor_data['Maxpulse'].agg(normalize)
health_monitor_data['Duration']=health_monitor_data['Duration'].agg(normalize)
health_monitor_data['Calories']=health_monitor_data['Calories'].agg(normalize)


health_monitor_data.head()
# Out:
# /tmp/ipython-input-3234946615.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_monitor_data['Pulse']=health_monitor_data['Pulse'].agg(normalize)
# /tmp/ipython-input-3234946615.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_monitor_data['Maxpulse']=health_monitor_data['Maxpulse'].agg(normalize)
# /tmp/ipython-input-3234946615.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
"""
Encoading categorical data

-One hot encoding
-Label encoding
"""
health_monitor_data['Pulse'].value_counts()
# Out:
# Pulse
#  0.026762    4
# -0.438900    4
# -0.749342    3
# -0.128459    3
#  2.199855    2
#  1.113308    2
#  0.181983    2
#  0.958088    2
# -1.680668    2
#  0.492425    1
# -1.991109    1
# -0.904563    1
#  0.802867    1
#  0.337204    1
# Name: count, dtype: int64

# %% [markdown]
# Eikhane aro kiso encoding kora lagbe. "Type" column er upore. kinto ei data set e Type column nai .

# %% [markdown]
# #Data spliting

# %%
#Data spliting
